# %%
# %%capture
# !pip install --upgrade pandas google-cloud-bigquery[pandas] six==1.13
import six
import pandas as pd 
from google.cloud import bigquery

# %%
creds = {
  "type": "service_account",
  "project_id": "my-project-1563213739189",
  "private_key_id": "7277894e3a6929c122724346b4a17a7479747efe",
  "private_key": "\nPxjByVO+IP7p6Io4S9DdhYoi\n-----END PRIVATE KEY-----\n",
  "client_email": "bq-sandbox@my-project-1563213739189.iam.gserviceaccount.com",
  "client_id": "102699358279752644267",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/bq-sandbox%40my-project-1563213739189.iam.gserviceaccount.com"
}

# %%
# %%capture
# !pip install --upgrade google-auth-oauthlib

# %%
import os 
os.getcwd()
# Out:
# '/Users/aleedom/Dropbox/Projects/Python Projects'

# %%
import sys 
sys.path.append('../../Credentials/')

# %%
from google_auth_oauthlib import flow 
appflow = flow.InstalledAppFlow.from_client_secrets_file(
'client_secrets.json',
scopes = ['https://www.googleapis.com/auth/bigquery'])
# token = 4/xgE9ITg9Mx37MvBQdywfEJqaBYoSvYFl3vtJtTzm7gG1Xh224us15Tk
if launch_browser: 
    appflow_run_local_server()
else: 
    appflow.run_console()
    
credentials = appflow.credentials
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-eb4b97ba5f84> in <module>
#       4 scopes = ['https://www.googleapis.com/auth/bigquery'])
#       5 # token = 4/xgE9ITg9Mx37MvBQdywfEJqaBYoSvYFl3vtJtTzm7gG1Xh224us15Tk
# ----> 6 if launch_browser:
#       7     appflow_run_local_server()
#       8 else:
#
# NameError: name 'launch_browser' is not defined

# %%
appflow = flow.InstalledAppFlow.from_client_secrets_file(
    'client_secrets.json',
    scopes=['https://www.googleapis.com/auth/bigquery'])

# %%
creds = appflow.run_local_server()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=852101288706-5jh5f21q27bf6oslm4jm76qaqdce0jgf.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fbigquery&state=3k2X7U44hXpFw6XL7PYeITjnoAr1ho&access_type=offline

# %%
creds = appflow.credentials

# %%
from google.cloud import bigquery
project = 'my-project-1563213739189' # could use json dictionary from above 
client = bigquery.Client(project=project, credentials=creds)

# %%
query_string = """ SELECT name, SUM(number) as total 
FROM `bigquery-public-data.usa_names.usa_1910_current`
WHERE name = 'William'
GROUP BY name;
"""

query_job = client.query(query_string)
for row in query_job.result(): 
    print('{}-{}'.format(row['name'], row['total']))
# Out:
# William-3901134

# %% [markdown]
# ## Getting data into a pandas df

# %%
# %%capture 
# !pip install --upgrade google-cloud-bigquery[bqstorage, pandas]

# %%
# %load_ext google.cloud.bigquery

# %%
s = '''SELECT
CONCAT(
    'https://stackoverflow.com/questions/',
    CAST(id as STRING)) as url,
view_count
FROM `bigquery-public-data.stackoverflow.posts_questions`
WHERE tags like '%google-bigquery%'
ORDER BY view_count DESC'''

# %%
execute = client.query(s)

# %%
out = pd.DataFrame(execute.result(),)

# %%
out.head()
# Out:
#                                                    0
# 0  (https://stackoverflow.com/questions/22879669,...
# 1  (https://stackoverflow.com/questions/35159967,...
# 2  (https://stackoverflow.com/questions/10604135,...
# 3  (https://stackoverflow.com/questions/13530967,...
# 4  (https://stackoverflow.com/questions/16609219,...

# %%
out['view_count'] = [x[1] for x in out[0]]

out['url'] = [x[0] for x in out[0]]

out = out.drop(columns = 0)

out = out[['url','view_count']]

out ## This is ugly and cumbersome -- there must be a better way to clean this
# Out:
#                                                 url  view_count
# 0      https://stackoverflow.com/questions/22879669       56103
# 1      https://stackoverflow.com/questions/35159967       51418
# 2      https://stackoverflow.com/questions/10604135       50814
# 3      https://stackoverflow.com/questions/13530967       46370
# 4      https://stackoverflow.com/questions/16609219       41266
# ...                                             ...         ...
# 11450  https://stackoverflow.com/questions/59105646          12
# 11451  https://stackoverflow.com/questions/58096707          12
# 11452  https://stackoverflow.com/questions/59075362          11
# 11453  https://stackoverflow.com/questions/58081414          11
# 11454  https://stackoverflow.com/questions/57571274           8
#
# [11455 rows x 2 columns]

# %% [markdown]
# #### Ok so we can get in... what's a good dataset?

# %%
s = """ 
SELECT * FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`;
"""

# %%
execute = client.query(s)
df = execute.result().to_dataframe()

# %%
df.groupby('start_station_name')['trip_id'].count().sort_values(ascending = False)
# Out:
# start_station_name
# 21st & Speedway @PCL          72799
# Riverside @ S. Lamar          40635
# City Hall / Lavaca & 2nd      36520
# 2nd & Congress                35307
# Rainey St @ Cummings          34758
#                               ...
# Marketing Event                   4
# Mobile Station @ Unplugged        4
# Eeyore's 2018                     2
# Stolen                            1
# Eeyore's 2017                     1
# Name: trip_id, Length: 190, dtype: int64

# %%
df.describe()
# Out:
#             trip_id  start_station_id  duration_minutes
# count  1.216805e+06      1.193651e+06      1.216805e+06
# mean   2.881493e+09      2.896732e+03      2.903296e+01
# std    4.484692e+09      5.809964e+02      1.187644e+02
# min    8.269930e+06      1.001000e+03      0.000000e+00
# 25%    1.571695e+07      2.537000e+03      6.000000e+00
# 50%    1.771458e+07      2.567000e+03      1.200000e+01
# 75%    9.900049e+09      3.619000e+03      2.600000e+01
# max    9.900353e+09      4.062000e+03      3.423800e+04

# %%
s2 = '''select * from `bigquery-public-data.austin_bikeshare.bikeshare_stations`'''
ex = client.query(s2)
df2 = ex.result().to_dataframe()

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Exploratory data analysis

# %%
df = df.dropna(subset = ['end_station_id'])

# %%
df = df.merge(df2[['station_id','latitude','longitude']].add_prefix('ending_'), left_on = 'end_station_id', right_on = 'ending_station_id')

# %%
df.to_csv('austin_bike_trips_intermediate.csv')

# %%
df.end_station_id.nunique()
# Out:
# 95

# %% [markdown]
# ### Compute distance matrix between all stations --> map in distance

# %%
# Find nunique stations --> 95 
# Create matrix of all 95 stations, fill values by api call 
unique_stations = df.end_station_id.unique()

# %%
# Out:
# 9025

# %%
import requests, json
api_key = "AIzaSyCyBqAIN-U2uoqxevg2R5-6dfkDU44Fv5I"
url = 'https://maps.googleapis.com/maps/api/distancematrix/json?origins='
# https://maps.googleapis.com/maps/api/distancematrix/json?origins='

# %%
url = 'https://maps.googleapis.com/maps/api/distancematrix/json?origins='
origin, dest = n['start_loc'], "&destinations=" + n['end_loc']
r = url + origin + dest + "&units=imperial" + '&transit_mode=bicycling' "&key=" + api_key

# %% [markdown]
# ###

# %%
# %matplotlib inline
n.sort_values('distance', ascending = False).iloc[:10].boxplot(by = 'start_station_name', column='distance', rot = 90)

# %%
test = requests.get("""https://maps.googleapis.com/maps/api/directions/json?"""\
"origin=sydney,au&destination=perth,au"\
"&waypoints=via:-37.81223%2C144.96254%7Cvia:-34.92788%2C138.60008"\
"&key=AIzaSyCyBqAIN-U2uoqxevg2R5-6dfkDU44Fv5I")

# %%
test.json()
# Out:
# {'geocoded_waypoints': [{'geocoder_status': 'OK',
#    'place_id': 'ChIJP3Sa8ziYEmsRUKgyFmh9AQM',
#    'types': ['colloquial_area', 'locality', 'political']},
#   {'geocoder_status': 'OK',
#    'place_id': 'ChIJU8OUocpC1moRoOMuf2CaEYI',
#    'types': ['street_address']},
#   {'geocoder_status': 'OK',
#    'place_id': 'ChIJCx_tO9jOsGoRmV1eXXXXJSc',
#    'types': ['establishment', 'point_of_interest', 'transit_station']},
#   {'geocoder_status': 'OK',
#    'place_id': 'ChIJPXNH22yWMioR0FXfNbXwBAM',
#    'types': ['colloquial_area', 'locality', 'political']}],
#  'routes': [{'bounds': {'northeast': {'lat': -30.955204, 'lng': 151.2092622},
#     'southwest': {'lat': -37.8273266, 'lng': 115.8604035}},
#    'copyrights': 'Map data ©2020 Google',
#    'legs': [{'distance': {'text': '4,300 km', 'value': 4299986},
#      'duration': {'text': '1 day 21 hours', 'value': 160882},
#      'end_address': 'Perth WA, Australia',
#      'end_location': {'lat': -31.9504886, 'lng': 115.8604035},
# ...
